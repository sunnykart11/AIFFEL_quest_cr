# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnykart11/AIFFEL_quest_cr/blob/main/Python/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1번
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')

        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')

        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        a,b=map(int,input('밑변, 높이를 입력하세요').split(','))
        result=a*b
        return result

    def trape(self):
        a,b,c=map(int,input('밑변, 윗변, 높이를 입력하세요').split(','))
        result=(a+b)*c/2
        return result

a = Square()
a.rect()
a.par()
a.trape()

# %%
#2번
# 문제 2-4. 추가 주문
# 추가 음료의 온도를 입력받고, 가격 리스트와 주문 리스트, 합계 금액을 업데이트합니다.
menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]

class Kiosk:
    def __init__(self):
        # 문제 2-1의 답을 입력하세요.
        self.menu = menu
        self.price = price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    def menu_select(self):
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트

        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일 때
            if 1 <= n & n <= len(menu):
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum = self.price[n-1]  # 합계 금액

                # 메뉴판에 없는 번호일 때
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")


        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3의 답을 입력하세요.
            if t==1:
                self.temp="HOT"
            elif t==2:
                self.temp="ICE"
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        self.order_menu.append(self.temp + ' ' + self.menu[n-1])  # 주문 리스트에 추가합니다.
        # 문제 2-2의 답을 입력하세요.
        print(self.temp, self.menu[n-1], ' : ', self.price_sum, '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.

        # 추가 주문 또는 지불
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1:
                # 추가 음료 온도
                # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.

                t = 0  # 기본값을 넣어주고
                while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
                    t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    # 문제 2-3의 답을 입력하세요.
                    if t==1:
                        self.temp="HOT"
                    elif t==2:
                        self.temp="ICE"
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")

                self.order_menu.append(self.temp+' ' +self.menu[n-1])
                self.order_price.append(self.price[n-1])

                print('추가 주문 음료', self.temp, self.menu[n-1], ':', self.price_sum, '원\n', '합계 : ', sum(self.order_price), '원')
            else :
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print(self.order_menu, self.order_price)  # 확인을 위한 리스트를 출력합니다.
                else :  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

Kiosk.menu_select = menu_select
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문

# %%
#3번

menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]

class Kiosk:
    def __init__(self):
        self.menu=menu
        self.price=price

    # 메뉴 출력 메서드
    def menu_print(self):
        print("메뉴는 다음과 같습니다")
        for i in range(len(self.menu)):
            print(i+1,self.menu[i],':',self.price[i])

    # 주문 메서드
    def menu_select(self):
        self.ordered_menu=[]
        self.ordered_sum=[]
        n=0
        while n<1 or n>len(self.menu):
            n=int(input("메뉴 번호를 입력하세요:"))
            if 1<=n<len(self.menu)+1:
                self.order=self.menu[n-1]
                self.money=self.price[n-1]
                print(self.order,":",self.money,"원")
            else:
                print("없는 메뉴입니다")

        self.ordered_menu.append(self.order)
        self.ordered_sum.append(self.money)

        while n!=0:
            n=int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))
            if 1<=n<len(self.menu)+1:
                self.ordered_menu.append(self.menu[n-1])
                self.ordered_sum.append(self.price[n-1])
                print(self.menu[n-1],"가 주문되었습니다: ",self.price[n-1])
            elif n==0:
                print("주문이 완료되었습니다.")
                print(self.ordered_menu, self.ordered_sum)
            else:
                print("없는 메뉴입니다")

    # 지불
    def pay(self):
        n=0
        while n!=1 and n!=2:
            n=int(input("결제 수단을 입력하세요. 카드는 1, 현금은 2"))
            if n==1:
                print("카드 꽂으세요")
            elif n==2:
                print("직원을 호출하겠습니다")
            else:
                print("다시 입력하세요")

    # 주문서 출력
    def table(self):
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

        for i in range(len(self.ordered_menu)):
            print(self.ordered_menu[i], ' : ', self.ordered_sum[i])

        print('합계 금액 :', sum(self.ordered_sum))

        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')

k=Kiosk()
k.menu_print()
k.menu_select()
k.pay()
k.table()
# Out:
# 메뉴는 다음과 같습니다
# 1 americano : 2000
# 2 latte : 3000
# 3 mocha : 3000
# 4 yuza_tea : 2500
# 5 green_tea : 2500
# 6 choco_latte : 3000
# 메뉴 번호를 입력하세요:1
# americano : 2000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 2
# latte 가 주문되었습니다:  3000
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 6
# choco_latte 가 주문되었습니다:  3000
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# ['americano', 'latte', 'choco_latte'] [2000, 3000, 3000]
# 결제 수단을 입력하세요. 카드는 1, 현금은 22
# 직원을 호출하겠습니다
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# americano  :  2000
# latte  :  3000
# choco_latte  :  3000
# 합계 금액 : 8000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
