# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnykart11/AIFFEL_quest_cr/blob/main/Python/Quest04/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# [기수1] 간단한 계산기 프로그램 만들기
# 사용자로부터 두 개의 정수와 연산자를 입력받아 계산 결과 출력.

def calculator():
  print("간단한 계산기 프로그램입니다.")

  try:
    num1 = int(input('첫 번째 정수를 입력하세요')) # 첫 번째 정수 입력
    num2 = int(input('두 번째 정수를 입력하세요')) # 두 번째 정수 입력
    operator = input('연산자를 입력하세요 (+,-,*,/,**):') # 연산자 입력
    if operator == '+':
      result = num1 + num2
    elif operator == '-':
      result = num1 - num2
    elif operator == '*':
      result = num1 * num2
    elif operator == '/': # 0으로 나누는 경우 예외 처리
         if num2 == 0:
          print('0으로 나눌 수 없습니다.')
          return
         result = num1 / num2
    elif operator =='**':
      result = num1 ** num2
    else:
      print("잘못된 연산자입니다. 다시 시도해주세요.")
      return
    print(f'결과: {num1}{operator}{num2} =  {result}')
  except ValueError:
    print('잘못된 입력입니다. 숫자를 입력하세요.')
calcurator()                                            # 키워드 스펠링 입력 오류
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02d8f08273a0> in <cell line: 27>()
#      25   except ValueError:
#      26     print('잘못된 입력입니다. 숫자를 입력하세요.')
# ---> 27 calcurator()
#      28
#      29
#
# NameError: name 'calcurator' is not defined

# %%
# [기수2] 파이썬을 사용하여 간단한 계산기 프로그램 만들기
# 사용자로부터 두개의 정수와 연산자(+,-,*,/,**)을 입력받아 계산 결과를 출력하는 프로그램

def calculator():
  print("간단한 계산기 프로그램입니다.")

  try:
    num1 = int(input('첫 번째 정수를 입력하세요')) # 첫 번째 정수 입력
    num2 = int(input('두 번째 정수를 입력하세요')) # 두 번째 정수 입력
    operator = input('연산자를 입력하세요 (+,-,*,/,**):') # 연산자 입력
    if operator == '+':
      result = num1 + num2
    elif operator == '-':
      result = num1 - num2
    elif operator == '*':
      result = num1 * num2
    elif operator == '/': # 0으로 나누는 경우 예외 처리
         if num2 == 0:
          print('0으로 나눌 수 없습니다.')
          return
         result = num1 / num2
    elif operator =='**':
      result = num1 ** num2
    else:
      print("잘못된 연산자입니다. 다시 시도해주세요.")
      return
    print(f'결과: {num1}{operator}{num2} =  {result}')
  except ValueError:
    print('잘못된 입력입니다. 숫자를 입력하세요.')
calculator()
# Out:
# 간단한 계산기 프로그램입니다.
# 첫 번째 정수를 입력하세요10
# 두 번째 정수를 입력하세요5
# 연산자를 입력하세요 (+,-,*,/,**):*
# 결과: 10*5 =  50

# %%
# [기수3] 파이썬을 사용하여 간단한 계산기 프로그램 만들기
# 사용자로부터 두개의 정수와 연산자(+,-,*,/,**)을 입력받아 계산 결과를 출력하는 프로그램

def calculator():
  print("간단한 계산기 프로그램입니다.")

  try:
    num1 = int(input('첫 번째 정수를 입력하세요')) # 첫 번째 정수 입력
    num2 = int(input('두 번째 정수를 입력하세요')) # 두 번째 정수 입력
    operator = input('연산자를 입력하세요 (+,-,*,/,**):') # 연산자 입력
    if operator == '+':
      result = num1 + num2
    elif operator == '-':
      result = num1 - num2
    elif operator == '*':
      result = num1 * num2
    elif operator == '/': # 0으로 나누는 경우 예외 처리
         if num2 == 0:
          print('0으로 나눌 수 없습니다.')
          return
         result = num1 / num2
    elif operator =='**':
      result = num1 ** num2
    else:
      print("잘못된 연산자입니다. 다시 시도해주세요.")
      return
    print(f'결과: {num1}{operator}{num2} =  {result}')
  except ValueError:
    print('잘못된 입력입니다. 숫자를 입력하세요.')
calculator()
# Out:
# 간단한 계산기 프로그램입니다.
# 첫 번째 정수를 입력하세요10
# 두 번째 정수를 입력하세요0
# 연산자를 입력하세요 (+,-,*,/,**):/
# 0으로 나눌 수 없습니다.

# %%
# [기수4]파이썬을 사용하여 간단한 계산기 프로그램 만들기
# 사용자로부터 두개의 정수와 연산자(+,-,*,/,**을 입력받아 계산 결과를 출력하는 프로그램

import math

def get_integer(prompt):
    """사용자로부터 정수를 입력받는 함수. 정수가 입력될 때까지 반복."""
    while True:
        try:
            return int(input(prompt))
        except ValueError:
            print("잘못된 입력입니다. 정수를 입력해주세요.")

def calculator():
    """간단한 계산기 프로그램."""
    print("간단한 계산기 프로그램입니다.")

    while True:
        # 첫 번째 정수 입력
        num1 = get_integer("첫 번째 정수를 입력하세요: ")

        # 두 번째 정수 입력
        num2 = get_integer("두 번째 정수를 입력하세요: ")

        # 연산자 입력
        operator = input("연산자를 입력하세요 (+, -, *, /, **): ")

        try:
            # 연산 수행
            if operator == '+':
                result = num1 + num2
            elif operator == '-':
                result = num1 - num2
            elif operator == '*':
                result = num1 * num2
            elif operator == '/':
                if num2 == 0:
                    raise ZeroDivisionError("0으로 나눌 수 없습니다.")
                result = num1 / num2
            elif operator == '**':
                result = math.pow(num1, num2)
            else:
                print("지원하지 않는 연산자입니다. 다시 입력해주세요.")
                continue

            # 결과 출력
            print(f"결과: {num1} {operator} {num2} = {result}")

        except ZeroDivisionError as e:
            print(f"오류: {e}")

        # 계속 계산할 것인지 확인
        cont = input("계속 계산하시겠습니까? (y/n): ").lower()
        if cont != 'y':
            print("계산기를 종료합니다.")
            break

# 프로그램 실행
calculator()

# 주요 변경점:
# 정수 입력 반복 처리:
# - get_integer 함수를 통해 정수가 입력될 때까지 반복해서 입력받습니다.
# - 잘못된 입력 시 ValueError를 처리하여 오류 메시지를 출력합니다.
#   나눗셈 예외 처리:
# - ZeroDivisionError를 명시적으로 처리하여 두 번째 정수가 0인 경우 적절한 메시지를 출력합니다.
#   제곱 연산:
# math.pow를 사용하여 제곱 연산(**)을 수행합니다.
# 계속 계산 여부:

# 사용자가 계속 계산할 것인지 묻고, y 이외의 입력 시 프로그램을 종료합니다.
# Out:
# 간단한 계산기 프로그램입니다.
# 첫 번째 정수를 입력하세요: 10
# 두 번째 정수를 입력하세요: 0
# 연산자를 입력하세요 (+, -, *, /, **): /
# 오류: 0으로 나눌 수 없습니다.
# 계속 계산하시겠습니까? (y/n): y
# 첫 번째 정수를 입력하세요: 2
# 두 번째 정수를 입력하세요: 3
# 연산자를 입력하세요 (+, -, *, /, **): **
# 결과: 2 ** 3 = 8.0
# 계속 계산하시겠습니까? (y/n): y
# 첫 번째 정수를 입력하세요: 3
# 두 번째 정수를 입력하세요: 7
# 연산자를 입력하세요 (+, -, *, /, **): -
# 결과: 3 - 7 = -4
# 계속 계산하시겠습니까? (y/n): n
# 계산기를 종료합니다.

# %%
def calculator():
  print("간단한 계산기 프로그램입니다.")
  while True:

   try:
     num1 = int(input('첫 번째 정수를 입력하세요')) # 첫 번째 정수 입력
     num2 = int(input('두 번째 정수를 입력하세요')) # 두 번째 정수 입력
     operator = input('연산자를 입력하세요 (+,-,*,/,**):') # 연산자 입력
     if operator == '+':
       result = num1 + num2
     elif operator == '-':
       result = num1 - num2
     elif operator == '*':
       result = num1 * num2
     elif operator == '/': # 0으로 나누는 경우 예외 처리
          if num2 == 0:
           print('0으로 나눌 수 없습니다.')
           return
          result = num1 / num2
     elif operator =='**':
       result = num1 ** num2
     else:
       print("잘못된 연산자입니다. 다시 시도해주세요.")
       return
     print(f'결과: {num1}{operator}{num2} =  {result}')
   except ValueError:
     print('잘못된 입력입니다. 숫자를 입력하세요.')
calculator()

# %%
#김선
# 1. 두 개의 정수와 연산자 입력 받기
# 2. 정수가 아닌 경우 ValueError : "잘못된 입력입니다. 정수를 입력해주세요."
# 3. 연산자가 나눗셈인 경우:두 번째 정수가 0인 경우:ZeroDivisionError
# 4. 6개 연산자 이외의 입력값일 경우:오류 메시지
# 5. 계속 계산할지

a,b=map(int,input().split())

# %%
# ValueError 처리 잘못된 시도 1

a,b=map(int,input().split())
if type(a) and type(b) is not int:                  # type(a) and type(b) is not int 조건 오류
   print("잘못된 입력입니다. 정수를 입력해주세요.")
# Out:
# 3.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-66b020db4513> in <cell line: 3>()
#       1 # ValueError 처리 잘못된 시도 1
#       2
# ----> 3 a,b=map(int,input().split())
#       4 if type(a) and type(b) is not int:
#       5    print("잘못된 입력입니다. 정수를 입력해주세요.")
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %%
try:
    a, b = map(int, input("두 개의 정수를 입력하세요: ").split())
    print(f"입력된 값: a = {a}, b = {b}")
except ValueError:
    print("잘못된 입력입니다. 정수를 입력해주세요.")

 # 예외 처리 사용 : try와 except를 사용하여 입력값이 정수로 변환되지 않을 경우 ValueError를 처리하도록 수정했습니다.
# Out:
# 두 개의 정수를 입력하세요: 10 ab
# 잘못된 입력입니다. 정수를 입력해주세요.

# %%
try:
    a=int(input("첫번째 정수를 입력하세요: "))
    b=int(input("두번째 정수를 입력하세요: "))
except ValueError:
    print("잘못된 입력입니다. 정수를 입력해주세요.")

# %% [markdown]
# **회 고**
# 구문 오류, 예외 처리에 대한 키워드와 코드 작성에 있어 배우게 되어 좋았고, 기존의 try- except문을 사용하여 계산기 프로그램 만들어 보면서 정수와 연산자로 계산하면서 출력해보는 좋은 시간이였다.

# %% [markdown]
# **회고(김선)** 처음에 try 구문 말고 if 구문으로 ValueError 메시지 뜨게 하려고 이런 저런 시도를 해보느라 시간이 많이 걸렸다. 결국 try 구문을 써야되나보다.
