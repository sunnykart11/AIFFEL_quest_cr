# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnykart11/AIFFEL_quest_cr/blob/main/%20Python/Python_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - [ ]  **2. 전체 코드에서 가장 핵심적이거나 가장 복잡하고 이해하기 어려운 부분에 작성된
# 주석 또는 doc string을 보고 해당 코드가 잘 이해되었나요?**
#     - 해당 코드 블럭을 왜 핵심적이라고 생각하는지 확인
#     - 해당 코드 블럭에 doc string/annotation이 달려 있는지 확인
#     - 해당 코드의 기능, 존재 이유, 작동 원리 등을 기술했는지 확인
#     - 주석을 보고 코드 이해가 잘 되었는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부
#
# - [ ]  **3. 에러가 난 부분을 디버깅하여 문제를 해결한 기록을 남겼거나
# 새로운 시도 또는 추가 실험을 수행해봤나요?**
#     - 문제 원인 및 해결 과정을 잘 기록하였는지 확인
#     - 프로젝트 평가 기준에 더해 추가적으로 수행한 나만의 시도,
#     실험이 기록되어 있는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부
#
# - [ ]  **4. 회고를 잘 작성했나요?**
#     - 주어진 문제를 해결하는 완성된 코드 내지 프로젝트 결과물에 대해
#     배운점과 아쉬운점, 느낀점 등이 기록되어 있는지 확인
#     - 전체 코드 실행 플로우를 그래프로 그려서 이해를 돕고 있는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부

# %% [markdown]
# <Python Quest01 회고>
# 이윤환
# 배운점: 문자열, 배열 뒤집기에 대한 다양한 방법에 대해 배웠고, 각 방법들의 특징과 장단점에 대해서 알게 되었다. 특히 드라이버와 네비게이터 역활을 수행하면서 안에 있는 것을 다시 정립할 수 있었고, 그루와의 생각 공유를 통해 사고가 확장되
# 느낀점: 학습하면서 봤던 것들이 직접 적용할 때에 또 다른 영역과 같이 느껴졌다. 하나 하나 꼼꼼하게 학습이 필요할 것 같다.

# %% [markdown]
# <Python Quest01 회고> 김선
# 배운점 : 하나의 결과를 도출하기 위해 여러가지 방법이 있다는 것을 느낄 수 있었다.
# 그루와의 대화를 통해 내가 미처 생각하지 못했던 부분과 잔 실수를 바로잡을 수 있어서 도움이 많이 되었다.

# %%
# 단어 입력 받기
word =input("입력값: \n")

# 입력 받은 단어 회문으로 만들기
word2 = "".join(reversed(word)) # word[::-1]도 실행 가능

# 제어문 사용
if word == word2:
  print("\n출력값: ")
  print(f'뒤집힌 단어는: {word} 입니다')
  print('입력된 단어는 회문입니다.')
# Out:
# 입력값:
# 우영우
#
# 출력값:
# 뒤집힌 단어는: 우영우 입니다
# 입력된 단어는 회문입니다.

# %%
while True:
  word_input =input("입력값: \n")
  re_word = word_input[::-1]
  if word_input != re_word:
    print(f"{word_input}은 회문이 아닙니다. 다시 입력하세요")
    continue
  elif word_input == re_word:
    print(f'출력값 :\n뒤집힌 단어는: {word_input} 입니다.\n입력된 단어는 회문입니다.')
    break
# Out:
# 입력값:
# 우영우
# 출력값 :
# 뒤집힌 단어는: 우영우 입니다.
# 입력된 단어는 회문입니다.
